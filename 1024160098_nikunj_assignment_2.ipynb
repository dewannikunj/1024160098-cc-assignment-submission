# %% [markdown]
# 1. Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10
# numbers in list now).
#
# i. Print L
#
# ii. Add two numbers of your choice to L — one using append() and one using insert() at a specific position.
# Print L after each and explain in a comment what changed.
#
# iii. Remove two elements from L — one using remove() and one using pop(). Print L after each.
#
# iv. Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.
#
# v. Use slicing to print the first three elements and the last three elements of L in a single line each.
#
# vi. Use list comprehension to create a new list containing only the elements of L that are greater than the
# average of L.

# %%
roll_no = 1024160098

L = [int(digit) * 10 for digit in str(roll_no)]

print("L =", L)
# Out:
# L = [10, 0, 20, 40, 10, 60, 0, 0, 90, 80]

# %%
L.append(55)
print("After append:", L)  # 55 is added at the end

L.insert(3, 75)
print("After insert:", L)  # 75 is inserted at index 3
# Out:
# After append: [10, 0, 20, 40, 10, 60, 0, 0, 90, 80, 55]
# After insert: [10, 0, 20, 75, 40, 10, 60, 0, 0, 90, 80, 55]

# %%
L.remove(55)
print("After remove:", L)  # First occurrence of 55 is removed

L.pop()
print("After pop:", L)  # Last element is removed
# Out:
# After remove: [10, 0, 20, 75, 40, 10, 60, 0, 0, 90, 80]
# After pop: [10, 0, 20, 75, 40, 10, 60, 0, 0, 90]

# %%
L.sort()
print("Ascending:", L)

L.sort(reverse=True)
print("Descending:", L)
# Out:
# Ascending: [0, 0, 0, 10, 10, 20, 40, 60, 75, 90]
# Descending: [90, 75, 60, 40, 20, 10, 10, 0, 0, 0]

# %%
print("First three elements:", L[:3])
print("Last three elements:", L[-3:])
# Out:
# First three elements: [90, 75, 60]
# Last three elements: [0, 0, 0]

# %%
average = int(sum(L) / len(L))

new_list = [x for x in L if x > average]

print("Average:", average)
print("Elements greater than average:", new_list)
# Out:
# Average: 30
# Elements greater than average: [90, 75, 60, 40]

# %% [markdown]
# 2. Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.
#
# i. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.
#
# ii. Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place —
# explain why in a one-line comment, referring to tuple immutability).
#
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present
# message if not.
#
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error
# Python raises, and explain in one line why this happens and how it differs from a list.
#
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a
# single line of unpacking.

# %%
scores = (10, 0, 20, 40, 10, 60, 0, 0)

# %%
highest = max(scores)
highest_index = scores.index(highest)

lowest = min(scores)
lowest_count = scores.count(lowest)

print("Highest score:", highest)
print("Index of highest score:", highest_index)
print("Lowest score:", lowest)
print("Lowest score appears:", lowest_count, "times")
# Out:
# Highest score: 60
# Index of highest score: 5
# Lowest score: 0
# Lowest score appears: 3 times

# %%
reversed_scores = list(scores[::-1])

print("Reversed tuple as list:", reversed_scores)

# Tuples cannot be reversed in place because tuples are immutable.
# Out:
# Reversed tuple as list: [0, 0, 60, 10, 40, 20, 0, 10]

# %%
score = int(input("Enter a score: "))

if score in scores:
    print("First occurrence index:", scores.index(score))
else:
    print("Score not present in the tuple")
# Out:
# Enter a score: 40
# First occurrence index: 3

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
first_score, second_score, *remaining_scores = scores

print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# First score: 10
# Second score: 0
# Remaining scores: [20, 40, 10, 60, 0, 0]

# %% [markdown]
# 3. Set the random seed to your own roll number using random.seed(your_roll_number) before generating
# your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed
# produces a different list, so this cannot be copied from a classmate).
#
# i. Generate a list of 100 random numbers between 100 and 900 (inclusive).
#
# ii. Count and print all odd numbers in the list.
#
# iii. Count and print all even numbers in the list.
#
# iv. Count and print all prime numbers in the list, and additionally build the actual list of prime numbers
# found using list comprehension.
#
# v. Print the number that occurs most frequently in your list, and how many times it occurs

# %%
import random

random.seed(1024160098)

numbers = [random.randint(100, 900) for _ in range(100)]

print("Random numbers:")
print(numbers)
# Out:
# Random numbers:
# [421, 526, 140, 360, 498, 429, 522, 534, 468, 480, 190, 265, 434, 779, 553, 197, 244, 257, 238, 822, 474, 209, 658, 519, 594, 793, 648, 320, 670, 779, 720, 763, 840, 862, 884, 531, 757, 643, 668, 720, 205, 584, 271, 143, 100, 811, 314, 687, 660, 468, 626, 163, 386, 687, 142, 739, 169, 198, 123, 167, 667, 700, 853, 710, 382, 300, 416, 786, 273, 582, 565, 739, 723, 625, 660, 678, 708, 135, 156, 593, 831, 534, 197, 869, 761, 286, 173, 514, 509, 243, 255, 587, 516, 134, 801, 324, 275, 417, 685, 271]

# %%
odd_numbers = [x for x in numbers if x % 2 != 0]

print("Odd numbers:", odd_numbers)
print("Number of odd numbers:", len(odd_numbers))
# Out:
# Odd numbers: [421, 429, 265, 779, 553, 197, 257, 209, 519, 793, 779, 763, 531, 757, 643, 205, 271, 143, 811, 687, 163, 687, 739, 169, 123, 167, 667, 853, 273, 565, 739, 723, 625, 135, 593, 831, 197, 869, 761, 173, 509, 243, 255, 587, 801, 275, 417, 685, 271]
# Number of odd numbers: 49

# %%
even_numbers = [x for x in numbers if x % 2 == 0]

print("Even numbers:", even_numbers)
print("Number of even numbers:", len(even_numbers))
# Out:
# Even numbers: [526, 140, 360, 498, 522, 534, 468, 480, 190, 434, 244, 238, 822, 474, 658, 594, 648, 320, 670, 720, 840, 862, 884, 668, 720, 584, 100, 314, 660, 468, 626, 386, 142, 198, 700, 710, 382, 300, 416, 786, 582, 660, 678, 708, 156, 534, 286, 514, 516, 134, 324]
# Number of even numbers: 51

# %%
def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True

prime_numbers = [x for x in numbers if is_prime(x)]

print("Prime numbers:", prime_numbers)
print("Number of prime numbers:", len(prime_numbers))
# Out:
# Prime numbers: [421, 197, 257, 757, 643, 271, 811, 163, 739, 167, 853, 739, 593, 197, 761, 173, 509, 587, 271]
# Number of prime numbers: 19

# %%
most_frequent = max(numbers, key=numbers.count)
frequency = numbers.count(most_frequent)

print("Most frequent number:", most_frequent)
print("It occurs:", frequency, "times")
# Out:
# Most frequent number: 534
# It occurs: 2 times

# %% [markdown]
# 4. Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for
# each digit} and set B = {digit × 9 for each digit}. Print both sets.
#
# vi. Find the union of A and B — all unique values across both sets.
#
# vii. Find the intersection of A and B — values common to both.
#
# viii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this
# differs from symmetric_difference().
#
# ix. Find the symmetric difference of A and B.
#
# x. Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().
#
# xi. Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain
# in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
digits = [1, 0, 2, 4, 1, 6, 0, 0]

A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}

print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 42, 14, 28}
# Set B: {0, 36, 9, 18, 54}

# %%
union_set = A.union(B)

print("Union of A and B:", union_set)
# Out:
# Union of A and B: {0, 36, 7, 9, 42, 14, 18, 54, 28}

# %%
intersection_set = A.intersection(B)

print("Intersection of A and B:", intersection_set)
# Out:
# Intersection of A and B: {0}

# %%
A_minus_B = A.difference(B)
B_minus_A = B.difference(A)

print("A - B:", A_minus_B)
print("B - A:", B_minus_A)

# difference() finds elements only in one specified set,
# while symmetric_difference() finds elements that are in either set but not both.
# Out:
# A - B: {42, 28, 14, 7}
# B - A: {9, 18, 36, 54}

# %%
symmetric_diff = A.symmetric_difference(B)

print("Symmetric difference:", symmetric_diff)
# Out:
# Symmetric difference: {7, 9, 14, 18, 28, 36, 42, 54}

# %%
print("Is A a subset of B?", A.issubset(B))
print("Is B a superset of A?", B.issuperset(A))
# Out:
# Is A a subset of B? False
# Is B a superset of A? False

# %%
X = int(input("Enter a value X: "))

A.discard(X)

print("Set A after discard:", A)

# discard() does not give an error if X is not present, unlike remove().
# Out:
# Enter a value X: 14
# Set A after discard: {0, 7, 42, 28}

# %% [markdown]
# 5. Consider the following dictionary:
#
# my_dict = {
#  "name": "<your name>",
#  "roll_no": "<your roll number>",
#  "branch": "<your branch>",
#  "age": <your age>,
#  "city": "<your home city>"
# }
#
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by
# hand — use pop() or dictionary comprehension so the code would work for any dictionary).
#
# ii. Add a new key “cgpa” with your CGPA as its value.
#
# iii. Update the value of “age” by increasing it by 1.
#
# iv. Delete the “branch” key using two different methods in two separate copies of the dictionary: once
# with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what
# does each return?).
#
# v. Iterate over your dictionary using .items() and print each key-value pair as “key → value”.
#
# vi. Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence
# using the in keyword and print a safe fallback message instead of letting the program crash.
#
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details.
# Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win”
# when both dictionaries share a key.
#
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your
# original dictionary where the value is a string.

# %%
my_dict = {
    "name": "Nikunj",
    "roll_no": "1024160098",
    "branch": "CSE",
    "age": 18,
    "city": "Hisar"
}

print(my_dict)
# Out:
# {'name': 'Nikunj', 'roll_no': '1024160098', 'branch': 'CSE', 'age': 18, 'city': 'Hisar'}

# %%
my_dict["location"] = my_dict.pop("city")

print(my_dict)
# Out:
# {'name': 'Nikunj', 'roll_no': '1024160098', 'branch': 'CSE', 'age': 18, 'location': 'Hisar'}

# %%
my_dict["cgpa"] = 7.81

print(my_dict)
# Out:
# {'name': 'Nikunj', 'roll_no': '1024160098', 'branch': 'CSE', 'age': 18, 'location': 'Hisar', 'cgpa': 7.81}

# %%
my_dict["age"] = my_dict["age"] + 1

print(my_dict)
# Out:
# {'name': 'Nikunj', 'roll_no': '1024160098', 'branch': 'CSE', 'age': 19, 'location': 'Hisar', 'cgpa': 7.81}

# %%
dict1 = my_dict.copy()
dict2 = my_dict.copy()

removed_branch = dict1.pop("branch")

print("After pop():", dict1)
print("Removed value:", removed_branch)

del dict2["branch"]

print("After del:", dict2)

# pop() removes the key and returns its value, while del removes the key without returning its value.
# Out:
# After pop(): {'name': 'Nikunj', 'roll_no': '1024160098', 'age': 19, 'location': 'Hisar', 'cgpa': 7.81}
# Removed value: CSE
# After del: {'name': 'Nikunj', 'roll_no': '1024160098', 'age': 19, 'location': 'Hisar', 'cgpa': 7.81}

# %%
for key, value in my_dict.items():
    print(key, "→", value)
# Out:
# name → Nikunj
# roll_no → 1024160098
# branch → CSE
# age → 19
# location → Hisar
# cgpa → 7.81

# %%
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("No email key found in the dictionary.")
# Out:
# No email key found in the dictionary.

# %%
friend_dict = {
    "name": "Mokksh",
    "roll_no": "1024160077",
    "branch": "COPC",
    "age": 20,
    "city": "Chandigarh"
}

merged_dict = {**my_dict, **friend_dict}

print("Merged dictionary:", merged_dict)
# Out:
# Merged dictionary: {'name': 'Mokksh', 'roll_no': '1024160077', 'branch': 'COPC', 'age': 20, 'location': 'Hisar', 'cgpa': 7.81, 'city': 'Chandigarh'}

# %%
string_values = {
    key: value for key, value in my_dict.items()
    if isinstance(value, str)
}

print("String values:", string_values)
# Out:
# String values: {'name': 'Nikunj', 'roll_no': '1024160098', 'branch': 'CSE', 'location': 'Hisar'}
